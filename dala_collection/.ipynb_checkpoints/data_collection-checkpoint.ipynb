# %%
import requests

# %%
URL = "https://stephen-king-api.onrender.com/api/books"
res = requests.get(URL)

# %%
res
# Out:
# <Response [200]>

# %%
json_data = res.json()

# %%
import pandas as pd

df = pd.json_normalize(json_data["data"])

df = df[["id", "Title", "Year", "ISBN"]]

# %%
df
# Out:
#     id          Title  Year               ISBN
# 0    1         Carrie  1974  978-0-385-08695-0
# 1    2    Salem's Lot  1975  978-0-385-00751-1
# 2    3    The Shining  1977  978-0-385-12167-5
# 3    4           Rage  1977  978-0-451-07645-8
# 4    5      The Stand  1978  978-0-385-12168-2
# ..  ..            ...   ...                ...
# 58  59   The Outsider  2018  978-1-50118-098-9
# 59  60      Elevation  2018  978-1-98210-231-9
# 60  61  The Institute  2019  978-1-98211-056-7
# 61  62          Later  2021  978-1-78909-649-1
# 62  63  Billy Summers  2021  978-1-982-17361-6
#
# [63 rows x 4 columns]

# %%
Link = "https://whoa.onrender.com/whoas/random"
res = requests.get(Link)

# %%
res
# Out:
# <Response [200]>

# %%
json_data = res.json()

# %%
json_data
# Out:
# [{'movie': 'The Night Before',
#   'year': 1988,
#   'release_date': '1988-04-15',
#   'director': 'Thom Eberhardt',
#   'character': 'Winston Connelly',
#   'movie_duration': '01:30:18',
#   'timestamp': '00:40:18',
#   'full_line': 'Whoa! OK! Whoa. Yeah. Whoa.',
#   'current_whoa_in_movie': 5,
#   'total_whoas_in_movie': 11,
#   'whoa_grouping': None,
#   'poster': 'https://images.ctfassets.net/a6ek464hq2lg/7GlORd4lwAJs0tPtqzPmy2/815d20f7c8f452f62e8e7fbeb1f29ace/fAm7q29aXTT0eDKPxuXzAGm6dKR.jpeg',
#   'video': {'1080p': 'https://videos.ctfassets.net/a6ek464hq2lg/3F0WN03KbcevBZG4s2RBtW/dd5f4d18b3cf09b472f0d883b2ce8386/The_Night_Before_5__1080p_.mp4',
#    '720p': 'https://videos.ctfassets.net/a6ek464hq2lg/32RVuZvFq3o689nG28ODsA/e035a27f053ff695591a72c3fd281199/The_Night_Before_5__720p_.mp4',
#    '480p': 'https://videos.ctfassets.net/a6ek464hq2lg/5XuZAcXG28AtmpAxnQlUw3/aa9916c3388d66eac0d0c6ec045e76f5/The_Night_Before_5__480p_.mp4',
#    '360p': 'https://videos.ctfassets.net/a6ek464hq2lg/1ijhJmKdlOueij4PdEY5WN/39984060940de5b474121de3b43dd511/The_Night_Before_5__360p_.mp4'},
#   'audio': 'https://assets.ctfassets.net/a6ek464hq2lg/1APGDa0a135CUHPBtCv8Gc/cfe412893437bd46daa433cba0396757/The_Night_Before_5_Audio.mp3'}]

# %%
df = pd.json_normalize(json_data[:])

# %%
df
# Out:
#               movie  year release_date        director         character  \
# 0  The Night Before  1988   1988-04-15  Thom Eberhardt  Winston Connelly
#
#   movie_duration timestamp                    full_line  \
# 0       01:30:18  00:40:18  Whoa! OK! Whoa. Yeah. Whoa.
#
#    current_whoa_in_movie  total_whoas_in_movie whoa_grouping  \
# 0                      5                    11          None
#
#                                               poster  \
# 0  https://images.ctfassets.net/a6ek464hq2lg/7GlO...
#
#                                                audio  \
# 0  https://assets.ctfassets.net/a6ek464hq2lg/1APG...
#
#                                          video.1080p  \
# 0  https://videos.ctfassets.net/a6ek464hq2lg/3F0W...
#
#                                           video.720p  \
# 0  https://videos.ctfassets.net/a6ek464hq2lg/32RV...
#
#                                           video.480p  \
# 0  https://videos.ctfassets.net/a6ek464hq2lg/5XuZ...
#
#                                           video.360p
# 0  https://videos.ctfassets.net/a6ek464hq2lg/1ijh...

# %%
# Web Scraping

URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)

# %%
print(res.status_code)
# Out:
# 200

# %%
if res.status_code == 200:
    print(res.headers)
with open("scraped_data/data1.html", "w", encoding='utf-8') as f:
    f.write(res.text)
# Out:
# {'Date': 'Mon, 27 Apr 2026 02:33:40 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=ELeWkWLRaE4%2F764oWE21F%2Bte9d60sGTYT0sEm4QePww%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1777257220"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=ELeWkWLRaE4%2F764oWE21F%2Bte9d60sGTYT0sEm4QePww%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1777257220"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': '9f2a6c796dfbd835-AMS', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
# Beautiful Soup
from bs4 import BeautifulSoup
with open("scraped_data/data1.html", "r") as f:
    html_content = f.read()
soup = BeautifulSoup(html_content, "lxml")

# %%
soup.find("h1")
soup.find("h3")
soup.h1
all_h3 = soup.find_all("h3")
all_countries = []
type(all_h3)
for h3 in all_h3:
    name = h3.get_text(strip=True)
    # print(h3.find_parent("div")["class"])
    population = h3.find_next("div").select("span.country-population")[0].get_text(strip=True)
    # print(h3.find_next("div").select_one("span.country-population").get_text(strip=True))
    # print(h3.attrs)
    all_countries.append([name, population])
# Out:
# 84000
# 4975593
# 29121286
# 86754
# 13254
# 2986952
# 2968000
# 13068161
# 0
# 41343201
# 57881
# 8205000
# 21515754
# 71566
# 26711
# 8303512
# 4590000
# 285653
